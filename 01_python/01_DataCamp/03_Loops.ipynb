# %% [markdown]
# # 1. While loop
#
# ```python
# while condition :
#     action
# ```
#
#
#
# ```python
# # breaking a loop
# while condition:
#     action
#     # Terminate the loop
#     break

# %% [markdown]
# # 2. For loop
#
# ```python
# # sequence = list, dict, etc..
# for value in sequence:
#     action
# ```
#
# ```python
# # Range :  Stop at end, action not doing. Add +1
# for value in range(start, end + 1):
#     action
# ```
#
# ## enumerate
# ```python
# areas = [11.25, 18.0, 20.0, 10.75, 9.50]
# for index, a in enumerate(areas) :
#     print(f"room {index}: {a}")
# ```
#
# ## dictionary
# ```python
# world = { "afghanistan":30.55,"albania":2.77, "algeria":39.21 }
# for key, value in world.items() :
#     print(key + " -- " + str(value))
# ```
#
# ## NumPu
# ###  1D array
# ```python
# for val in my_array :
#     print(val)   → print each val
# ```
#
# ### 2D array
#
# ```python
# for val in my_array :
#     print(val)      → print a list of val for each D
# ```
# ```python
# for val in np.nditer(my_array) :
#     print(val)      → print each element for first D, then second D
# ```
#
# ## DataFrame
#
# ```python
# import pandas as pd
# brics = pd.read_csv("brics.csv", index_col = 0)
# for val in brics :
#     print(val)   → print each column name
# ```
#
# ### iterrows
# ```python
# import pandas as pd
# brics = pd.read_csv("brics.csv", index_col = 0)
# for lab, row in brics.iterrows():
#     print(lab + ": " + row["capital"])   → lab = index
# ```
#
# ### Apply
# ```python
# import pandas as pd
# brics = pd.read_csv("brics.csv", index_col = 0)
# brics["name_length"] = brics["country"].apply(len)print(brics)
# ```
